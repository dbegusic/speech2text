# %%
import numpy as np
import soundfile as sf
from pydub.silence import split_on_silence
from pydub import AudioSegment

from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import torch

import sys
sys.path.append("/usr/local/bin/ffmpeg")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Load model and tokenizer.
processor = Wav2Vec2Processor.from_pretrained(f"classla/wav2vec2-xls-r-parlaspeech-hr")
model = Wav2Vec2ForCTC.from_pretrained(f"classla/wav2vec2-xls-r-parlaspeech-hr")

# Load audio sample. Must be in wav format with sample rate 16000.
speech = AudioSegment.from_wav(f"data/VRH-121 - 27.05.2022.wav")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Create chunks of loaded audio based on detected silence
def calculate_chunks(speech: AudioSegment) -> None:
    chunks=split_on_silence (
        # Use the loaded audio
        speech, 
        # Specify that a silent chunk must be at least 200 ms long
        min_silence_len=200,
        # Consider a chunk silent if it's quieter than -50 dBFS
        silence_thresh=-50,
        # After splitting add 200 ms of treshold
        keep_silence=200,
        # Calculate every 10 ms
        seek_step=5
    )
    # Make sure each chunk has sample rate 16000
    for chunk in chunks:
        chunk.frame_rate = 16000
    # Export chunks in wav format.
    for i in range(len(chunks)):
        chunks[i].export(out_f=f"data/chunks/chunk_"+str(i)+".wav", format="wav") 
    return

# Load wav audio file and parse using specified model and processor
def load_parse_wav(model: Wav2Vec2ForCTC, processor: Wav2Vec2Processor, filename: str) -> (np.ndarray, float):
    # Read the wav file
    speech, sample_rate = sf.read(filename)
    input_values = processor(speech, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    # Calculate duration
    seconds = len(speech) / sample_rate
    # Retrieve logits
    logits = model.to(device)(input_values).logits
    return logits, seconds

# Transribe parsed audio file using specified processor.
def get_transcription(processor: Wav2Vec2Processor, logits: np.ndarray) -> str:
    # Take argmax and decode.
    predicted_ids = torch.argmax(logits, dim=-1)
    transcription = processor.decode(predicted_ids[0]).lower()
    return transcription

def normalize(sound: AudioSegment, reference: int) -> AudioSegment:
    new_levels = reference - sound.dBFS
    return sound.apply_gain(new_levels)

def normalize_chunks() -> None:
    for i in range(234):
        chunk = AudioSegment.from_wav(f"data/chunks/chunk_{str(i)}.wav")
        chunk_normalized = normalize(chunk, -3)
        # Export normalized chunks in wav format
        chunk_normalized.export(out_f=f"data/chunks_normalized/chunk_normalized_{str(i)}.wav", format="wav")
    return

# %%
calculate_chunks(speech)
normalize_chunks()

transcription = ""

for i in range(0, 234):
    logits, seconds = load_parse_wav(model, processor, f"data/chunks_normalized/chunk_normalized_{str(i)}.wav")
    print(f"chunk_{str(i)}\t", "seconds: ", seconds)
    if seconds > 1.0:
        print(f"\ttranscribing...")
        transcription += get_transcription(processor,logits) + " "
    else:
        print(f"\tignoring...")
transcription = transcription[0:-1]

with open(f"transcription_normalized.txt", "w") as f:
    f.write(transcription)
# Out:
# chunk_0	 seconds:  10.875
# 	transcribing...
# chunk_1	 seconds:  0.657
# 	ignoring...
# chunk_2	 seconds:  18.483
# 	transcribing...
# chunk_3	 seconds:  8.37
# 	transcribing...
# chunk_4	 seconds:  30.19
# 	transcribing...
# chunk_5	 seconds:  9.037
# 	transcribing...
# chunk_6	 seconds:  7.91
# 	transcribing...
# chunk_7	 seconds:  0.8
# 	ignoring...
# chunk_8	 seconds:  9.348
# 	transcribing...
# chunk_9	 seconds:  8.857
# 	transcribing...
# chunk_10	 seconds:  2.298
# 	transcribing...
# chunk_11	 seconds:  8.645
# 	transcribing...
# chunk_12	 seconds:  6.507
# 	transcribing...
# chunk_13	 seconds:  0.638
# 	ignoring...
# chunk_14	 seconds:  9.222
# 	transcribing...
# chunk_15	 seconds:  10.348
# 	transcribing...
# chunk_16	 seconds:  0.417
# 	ignoring...
# chunk_17	 seconds:  0.835
# 	ignoring...
# chunk_18	 seconds:  10.41
# 	transcribing...
# chunk_19	 seconds:  8.813
# 	transcribing...
# chunk_20	 seconds:  7.345
# 	transcribing...
# chunk_21	 seconds:  3.232
# 	transcribing...
# chunk_22	 seconds:  1.69
# 	transcribing...
# chunk_23	 seconds:  5.405
# 	transcribing...
# chunk_24	 seconds:  0.393
# 	ignoring...
# chunk_25	 seconds:  4.725
# 	transcribing...
# chunk_26	 seconds:  6.355
# 	transcribing...
# chunk_27	 seconds:  2.86
# 	transcribing...
# chunk_28	 seconds:  1.32
# 	transcribing...
# chunk_29	 seconds:  2.017
# 	transcribing...
# chunk_30	 seconds:  2.378
# 	transcribing...
# chunk_31	 seconds:  1.03
# 	transcribing...
# chunk_32	 seconds:  1.407
# 	transcribing...
# chunk_33	 seconds:  3.733
# 	transcribing...
# chunk_34	 seconds:  1.365
# 	transcribing...
# chunk_35	 seconds:  1.535
# 	transcribing...
# chunk_36	 seconds:  6.58
# 	transcribing...
# chunk_37	 seconds:  2.867
# 	transcribing...
# chunk_38	 seconds:  1.748
# 	transcribing...
# chunk_39	 seconds:  9.785
# 	transcribing...
# chunk_40	 seconds:  5.97
# 	transcribing...
# chunk_41	 seconds:  6.48
# 	transcribing...
# chunk_42	 seconds:  5.425
# 	transcribing...
# chunk_43	 seconds:  4.177
# 	transcribing...
# chunk_44	 seconds:  13.73
# 	transcribing...
# chunk_45	 seconds:  5.22
# 	transcribing...
# chunk_46	 seconds:  5.618
# 	transcribing...
# chunk_47	 seconds:  0.665
# 	ignoring...
# chunk_48	 seconds:  8.4
# 	transcribing...
# chunk_49	 seconds:  1.895
# 	transcribing...
# chunk_50	 seconds:  7.735
# 	transcribing...
# chunk_51	 seconds:  17.295
# 	transcribing...
# chunk_52	 seconds:  10.582
# 	transcribing...
# chunk_53	 seconds:  3.95
# 	transcribing...
# chunk_54	 seconds:  7.233
# 	transcribing...
# chunk_55	 seconds:  3.357
# 	transcribing...
# chunk_56	 seconds:  15.628
# 	transcribing...
# chunk_57	 seconds:  11.552
# 	transcribing...
# chunk_58	 seconds:  8.678
# 	transcribing...
# chunk_59	 seconds:  28.072
# 	transcribing...
# chunk_60	 seconds:  2.528
# 	transcribing...
# chunk_61	 seconds:  3.972
# 	transcribing...
# chunk_62	 seconds:  2.96
# 	transcribing...
# chunk_63	 seconds:  0.363
# 	ignoring...
# chunk_64	 seconds:  0.78
# 	ignoring...
# chunk_65	 seconds:  19.552
# 	transcribing...
# chunk_66	 seconds:  31.238
# 	transcribing...
# chunk_67	 seconds:  38.765
# 	transcribing...
# chunk_68	 seconds:  10.09
# 	transcribing...
# chunk_69	 seconds:  14.685
# 	transcribing...
# chunk_70	 seconds:  7.207
# 	transcribing...
# chunk_71	 seconds:  3.185
# 	transcribing...
# chunk_72	 seconds:  5.825
# 	transcribing...
# chunk_73	 seconds:  3.193
# 	transcribing...
# chunk_74	 seconds:  0.57
# 	ignoring...
# chunk_75	 seconds:  13.437
# 	transcribing...
# chunk_76	 seconds:  10.473
# 	transcribing...
# chunk_77	 seconds:  0.797
# 	ignoring...
# chunk_78	 seconds:  9.43
# 	transcribing...
# chunk_79	 seconds:  4.745
# 	transcribing...
# chunk_80	 seconds:  13.1
# 	transcribing...
# chunk_81	 seconds:  4.623
# 	transcribing...
# chunk_82	 seconds:  2.035
# 	transcribing...
# chunk_83	 seconds:  0.4
# 	ignoring...
# chunk_84	 seconds:  1.575
# 	transcribing...
# chunk_85	 seconds:  4.19
# 	transcribing...
# chunk_86	 seconds:  48.945
# 	transcribing...
# chunk_87	 seconds:  15.0
# 	transcribing...
# chunk_88	 seconds:  3.352
# 	transcribing...
# chunk_89	 seconds:  65.968
# 	transcribing...
# chunk_90	 seconds:  5.295
# 	transcribing...
# chunk_91	 seconds:  5.205
# 	transcribing...
# chunk_92	 seconds:  5.03
# 	transcribing...
# chunk_93	 seconds:  10.43
# 	transcribing...
# chunk_94	 seconds:  3.265
# 	transcribing...
# chunk_95	 seconds:  1.202
# 	transcribing...
# chunk_96	 seconds:  3.968
# 	transcribing...
# chunk_97	 seconds:  3.24
# 	transcribing...
# chunk_98	 seconds:  0.525
# 	ignoring...
# chunk_99	 seconds:  13.135
# 	transcribing...
# chunk_100	 seconds:  0.532
# 	ignoring...
# chunk_101	 seconds:  11.615
# 	transcribing...
# chunk_102	 seconds:  0.455
# 	ignoring...
# chunk_103	 seconds:  3.388
# 	transcribing...
# chunk_104	 seconds:  6.53
# 	transcribing...
# chunk_105	 seconds:  0.527
# 	ignoring...
# chunk_106	 seconds:  13.213
# 	transcribing...
# chunk_107	 seconds:  9.51
# 	transcribing...
# chunk_108	 seconds:  3.917
# 	transcribing...
# chunk_109	 seconds:  2.545
# 	transcribing...
# chunk_110	 seconds:  29.605
# 	transcribing...
# chunk_111	 seconds:  8.785
# 	transcribing...
# chunk_112	 seconds:  11.998
# 	transcribing...
# chunk_113	 seconds:  5.265
# 	transcribing...
# chunk_114	 seconds:  12.49
# 	transcribing...
# chunk_115	 seconds:  15.79
# 	transcribing...
# chunk_116	 seconds:  7.997
# 	transcribing...
# chunk_117	 seconds:  4.078
# 	transcribing...
# chunk_118	 seconds:  5.097
# 	transcribing...
# chunk_119	 seconds:  2.528
# 	transcribing...
# chunk_120	 seconds:  4.332
# 	transcribing...
# chunk_121	 seconds:  7.25
# 	transcribing...
# chunk_122	 seconds:  0.653
# 	ignoring...
# chunk_123	 seconds:  1.915
# 	transcribing...
# chunk_124	 seconds:  7.37
# 	transcribing...
# chunk_125	 seconds:  3.76
# 	transcribing...
# chunk_126	 seconds:  35.77
# 	transcribing...
# chunk_127	 seconds:  8.165
# 	transcribing...
# chunk_128	 seconds:  0.402
# 	ignoring...
# chunk_129	 seconds:  11.113
# 	transcribing...
# chunk_130	 seconds:  8.81
# 	transcribing...
# chunk_131	 seconds:  4.527
# 	transcribing...
# chunk_132	 seconds:  19.953
# 	transcribing...
# chunk_133	 seconds:  3.585
# 	transcribing...
# chunk_134	 seconds:  3.215
# 	transcribing...
# chunk_135	 seconds:  12.992
# 	transcribing...
# chunk_136	 seconds:  2.765
# 	transcribing...
# chunk_137	 seconds:  1.873
# 	transcribing...
# chunk_138	 seconds:  6.107
# 	transcribing...
# chunk_139	 seconds:  5.443
# 	transcribing...
# chunk_140	 seconds:  2.1
# 	transcribing...
# chunk_141	 seconds:  3.195
# 	transcribing...
# chunk_142	 seconds:  6.482
# 	transcribing...
# chunk_143	 seconds:  12.173
# 	transcribing...
# chunk_144	 seconds:  5.962
# 	transcribing...
# chunk_145	 seconds:  4.065
# 	transcribing...
# chunk_146	 seconds:  3.428
# 	transcribing...
# chunk_147	 seconds:  4.205
# 	transcribing...
# chunk_148	 seconds:  0.68
# 	ignoring...
# chunk_149	 seconds:  7.44
# 	transcribing...
# chunk_150	 seconds:  3.185
# 	transcribing...
# chunk_151	 seconds:  13.19
# 	transcribing...
# chunk_152	 seconds:  4.415
# 	transcribing...
# chunk_153	 seconds:  7.455
# 	transcribing...
# chunk_154	 seconds:  12.455
# 	transcribing...
# chunk_155	 seconds:  2.862
# 	transcribing...
# chunk_156	 seconds:  2.543
# 	transcribing...
# chunk_157	 seconds:  1.905
# 	transcribing...
# chunk_158	 seconds:  4.16
# 	transcribing...
# chunk_159	 seconds:  2.415
# 	transcribing...
# chunk_160	 seconds:  5.982
# 	transcribing...
# chunk_161	 seconds:  5.148
# 	transcribing...
# chunk_162	 seconds:  3.227
# 	transcribing...
# chunk_163	 seconds:  0.548
# 	ignoring...
# chunk_164	 seconds:  13.645
# 	transcribing...
# chunk_165	 seconds:  3.04
# 	transcribing...
# chunk_166	 seconds:  9.287
# 	transcribing...
# chunk_167	 seconds:  6.588
# 	transcribing...
# chunk_168	 seconds:  9.915
# 	transcribing...
# chunk_169	 seconds:  5.482
# 	transcribing...
# chunk_170	 seconds:  3.88
# 	transcribing...
# chunk_171	 seconds:  1.678
# 	transcribing...
# chunk_172	 seconds:  5.712
# 	transcribing...
# chunk_173	 seconds:  7.503
# 	transcribing...
# chunk_174	 seconds:  2.737
# 	transcribing...
# chunk_175	 seconds:  1.218
# 	transcribing...
# chunk_176	 seconds:  4.867
# 	transcribing...
# chunk_177	 seconds:  25.123
# 	transcribing...
# chunk_178	 seconds:  11.98
# 	transcribing...
# chunk_179	 seconds:  8.92
# 	transcribing...
# chunk_180	 seconds:  0.32
# 	ignoring...
# chunk_181	 seconds:  6.995
# 	transcribing...
# chunk_182	 seconds:  13.21
# 	transcribing...
# chunk_183	 seconds:  9.665
# 	transcribing...
# chunk_184	 seconds:  10.935
# 	transcribing...
# chunk_185	 seconds:  19.257
# 	transcribing...
# chunk_186	 seconds:  12.268
# 	transcribing...
# chunk_187	 seconds:  4.705
# 	transcribing...
# chunk_188	 seconds:  0.8
# 	ignoring...
# chunk_189	 seconds:  10.295
# 	transcribing...
# chunk_190	 seconds:  3.675
# 	transcribing...
# chunk_191	 seconds:  3.485
# 	transcribing...
# chunk_192	 seconds:  1.045
# 	transcribing...
# chunk_193	 seconds:  0.795
# 	ignoring...
# chunk_194	 seconds:  6.905
# 	transcribing...
# chunk_195	 seconds:  8.735
# 	transcribing...
# chunk_196	 seconds:  0.85
# 	ignoring...
# chunk_197	 seconds:  3.69
# 	transcribing...
# chunk_198	 seconds:  6.43
# 	transcribing...
# chunk_199	 seconds:  1.345
# 	transcribing...
# chunk_200	 seconds:  0.415
# 	ignoring...
# chunk_201	 seconds:  11.6
# 	transcribing...
# chunk_202	 seconds:  8.347
# 	transcribing...
# chunk_203	 seconds:  11.223
# 	transcribing...
# chunk_204	 seconds:  9.622
# 	transcribing...
# chunk_205	 seconds:  7.453
# 	transcribing...
# chunk_206	 seconds:  2.087
# 	transcribing...
# chunk_207	 seconds:  9.38
# 	transcribing...
# chunk_208	 seconds:  61.243
# 	transcribing...
# chunk_209	 seconds:  0.38
# 	ignoring...
# chunk_210	 seconds:  5.342
# 	transcribing...
# chunk_211	 seconds:  6.0
# 	transcribing...
# chunk_212	 seconds:  8.75
# 	transcribing...
# chunk_213	 seconds:  5.678
# 	transcribing...
# chunk_214	 seconds:  4.327
# 	transcribing...
# chunk_215	 seconds:  1.325
# 	transcribing...
# chunk_216	 seconds:  3.205
# 	transcribing...
# chunk_217	 seconds:  8.513
# 	transcribing...
# chunk_218	 seconds:  16.15
# 	transcribing...
# chunk_219	 seconds:  0.995
# 	ignoring...
# chunk_220	 seconds:  10.415
# 	transcribing...
# chunk_221	 seconds:  6.0
# 	transcribing...
# chunk_222	 seconds:  8.115
# 	transcribing...
# chunk_223	 seconds:  3.375
# 	transcribing...
# chunk_224	 seconds:  4.907
# 	transcribing...
# chunk_225	 seconds:  6.448
# 	transcribing...
# chunk_226	 seconds:  4.017
# 	transcribing...
# chunk_227	 seconds:  7.705
# 	transcribing...
# chunk_228	 seconds:  1.905
# 	transcribing...
# chunk_229	 seconds:  12.243
# 	transcribing...
# chunk_230	 seconds:  6.42
# 	transcribing...
# chunk_231	 seconds:  3.22
# 	transcribing...
# chunk_232	 seconds:  16.277
# 	transcribing...
# chunk_233	 seconds:  0.338
# 	ignoring...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

def chunk_durations() -> pd.DataFrame:
    durations = []
    for i in range(0, 234):
        chunk = AudioSegment.from_wav(f"data/chunks/chunk_{str(i)}.wav")
        durations.append(chunk.duration_seconds)
    return pd.DataFrame(durations, columns=["duration"])

def duration_histogram(df: pd.DataFrame, referent_max_value: float) -> None:
    f, ax = plt.subplots(figsize=(20, 13))
    sns.histplot(x="duration", data=df, label="Duration", kde=True, stat="count")
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    plt.xlabel("Duration", fontsize=25)
    plt.ylabel("Count", fontsize=25)
    plt.show()

# %%
durations = chunk_durations()
referent_max_value = max(durations["duration"])
print(f"Number of chunks with duration less than equal 1.0 seconds: {sum(durations['duration'].apply(lambda x: 1 if x<=1 else 0))}")
print(f"Mean duration of all chunks with duration greater than 1.0 seconds: {durations['duration'].apply(lambda x: 0 if x<=1 else x).mean()}")
duration_histogram(durations, referent_max_value=referent_max_value)
# Out:
# Number of chunks with duration less than equal 1.0 seconds: 28
# Mean duration of all chunks with duration greater than 1.0 seconds: 7.37318376068376

# %%
def word_error_plot(df: pd.DataFrame, referent_max_value: float) -> None:
    f, ax = plt.subplots(figsize=(20, 13))
    sns.barplot(x="error", y="value", hue="Error Type", data=df, palette=["#FF0048", "#FCA022", "#2ABFCC"])
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    plt.xlabel("", fontsize=25)
    plt.ylabel("Word Error Rate", fontsize=25)
    plt.legend(fontsize=20)
    plt.show()

# %%
data = {
    "error": ["Original", "Original", "Original", "Normalized", "Normalized", "Normalized"],
    "value": [176, 29, 67, 197, 25, 97],
    "Error Type": ["HACHECK Word Error", "HACHECK Stylistic Error", "Nonexistent Words", "HACHECK Word Error", "HACHECK Stylistic Error", "Nonexistent Words"]
}
errors=pd.DataFrame(data, columns=["error", "value", "Error Type"])
word_error_plot(errors,referent_max_value=220)
